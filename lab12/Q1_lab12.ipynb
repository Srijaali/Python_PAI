# %% [markdown]
# Q1: Download any clustering dataset from internet and after finding how many optimum number of
# clusters should be formed using elbow curve, apply k-means on it.

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

data = pd.read_csv('wine-clustering.csv')
data.head(5)
data.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  ...         Hue       OD280      Proline
# count  178.000000  178.000000  178.000000  ...  178.000000  178.000000   178.000000
# mean    13.000618    2.336348    2.366517  ...    0.957449    2.611685   746.893258
# std      0.811827    1.117146    0.274344  ...    0.228572    0.709990   314.907474
# min     11.030000    0.740000    1.360000  ...    0.480000    1.270000   278.000000
# 25%     12.362500    1.602500    2.210000  ...    0.782500    1.937500   500.500000
# 50%     13.050000    1.865000    2.360000  ...    0.965000    2.780000   673.500000
# 75%     13.677500    3.082500    2.557500  ...    1.120000    3.170000   985.000000
# max     14.830000    5.800000    3.230000  ...    1.710000    4.000000  1680.000000
#
# [8 rows x 13 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
pd.DataFrame(scaled_data)
pd.DataFrame(scaled_data).describe()
# Out:
#                  0             1             2   ...            10            11            12
# count  1.780000e+02  1.780000e+02  1.780000e+02  ...  1.780000e+02  1.780000e+02  1.780000e+02
# mean  -8.382808e-16 -1.197544e-16 -8.370333e-16  ...  1.995907e-16  3.193450e-16 -1.596725e-16
# std    1.002821e+00  1.002821e+00  1.002821e+00  ...  1.002821e+00  1.002821e+00  1.002821e+00
# min   -2.434235e+00 -1.432983e+00 -3.679162e+00  ... -2.094732e+00 -1.895054e+00 -1.493188e+00
# 25%   -7.882448e-01 -6.587486e-01 -5.721225e-01  ... -7.675624e-01 -9.522483e-01 -7.846378e-01
# 50%    6.099988e-02 -4.231120e-01 -2.382132e-02  ...  3.312687e-02  2.377348e-01 -2.337204e-01
# 75%    8.361286e-01  6.697929e-01  6.981085e-01  ...  7.131644e-01  7.885875e-01  7.582494e-01
# max    2.259772e+00  3.109192e+00  3.156325e+00  ...  3.301694e+00  1.960915e+00  2.971473e+00
#
# [8 rows x 13 columns]

# %%
kmean = KMeans(n_clusters=3 , init='k-means++')
kmean.fit(scaled_data)
# Out:
# KMeans(n_clusters=3)

# %%
kmean.inertia_
# Out:
# 1278.7607763668154

# %%
#fitting multple k-means algorithm and storing values in an empty list
SSE=[]
for k in range(1,20):

  kmean = KMeans(n_clusters=k , init='k-means++')
  kmean.fit(scaled_data)
  SSE.append(kmean.inertia_)

#converting results into DataFrame and plotting them
frame = pd.DataFrame({'Cluster':range(1,20) , 'SSE':SSE})
plt.figure(figsize=(12,6))
plt.plot(frame['Cluster'], frame['SSE'] , marker='o', color='red')
plt.xlabel('No. of Cluster')
plt.ylabel('SSE')
plt.show()

# %%
#k-means using 10 clusters and k-means++ initialization
kmeans = KMeans(n_clusters=11 , init='k-means++')
kmeans.fit(scaled_data)
prediction= kmeans.predict(scaled_data)

frame = pd.DataFrame(scaled_data)
frame['cluster'] = prediction
frame['cluster'].value_counts()
# Out:
# cluster
# 4     27
# 0     23
# 2     23
# 1     22
# 5     19
# 8     16
# 3     16
# 7     14
# 10     8
# 6      7
# 9      3
# Name: count, dtype: int64
